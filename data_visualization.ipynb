# %% [markdown]
# MATPLOTLIB Tutorial

# %%
from matplotlib import pylab
print(pylab._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_1153/1052983455.py in <module>
#       1 from matplotlib import pylab
# ----> 2 print(pylab._version_)
#
# AttributeError: module 'matplotlib.pylab' has no attribute '_version_'

# %%
import numpy as np
x = np.linspace(0,10,25)
y = x * x/2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [ 0.          0.08680556  0.34722222  0.78125     1.38888889  2.17013889
#   3.125       4.25347222  5.55555556  7.03125     8.68055556 10.50347222
#  12.5        14.67013889 17.01388889 19.53125    22.22222222 25.08680556
#  28.125      31.33680556 34.72222222 38.28125    42.01388889 45.92013889
#  50.        ]

# %%
pylab.plot(x,y, 'r') # r stand for red

# %%
pylab.subplot(1,2,1) # row , columns , indexes
pylab.plot(x, y, 'r--') #color and line style
pylab.subplot(1,2,1)
pylab.plot(y, x ,'g*')

# %%
pylab.subplot(1,2,1) # row , columns , indexes
pylab.plot(x, y, 'r--') #color and line style
pylab.subplot(1,2,2)
pylab.plot(y, x ,'g*')

# %% [markdown]
# #Operator Description
# fig.add_axes() = initialize suplot a = fig.add_suplot(222)
# fig.b = plt.subplots(nrows=3,nclos=2=Adds subplot
# ax = plt.subplots(2,2) = creates sublots

# %% [markdown]
# **SEABORN**

# %%
import seaborn as sns
data = sns.load_dataset("iris")

#draw a lineplot
sns.lineplot(x="sepal_length", y = "sepal_width", data = data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.title('Title using Matplotlib Function')

plt.show()

# %%
#using xlim and ylim
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.xlim(4)
plt.ylim(2)

#changing the color to dark
sns.set_style("dark")
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

#changing the color to dark
sns.set_style("ticks") #darkgrid,whitegrid,dark,white
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

#changing the color to dark
sns.despine()
plt.show()

# %%
plt.figure(figsize =(2,4))
sns.lineplot(x="sepal_length", y="sepal_width", data = data)

sns.despine()
plt.show()

# %%
#scaling the plots
sns.lineplot(x="sepal_length", y="sepal_width", data = data)

sns.set_context("paper") #notebook,talk,poster,paper
plt.show()

# %%
#setting the style temporariyly
def plot():
    sns.lineplot(x="petal_length",y="petal_width", data = data)
    
    with sns.axes_style('darkgrid'):
        #adding the subplot
        plt.subplot(211)
        plot()
        
    plt.subplot(212)
    plot()

# %%
# using subplot2grid()
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def graph():
    sns.lineplot(x="sepal_length",y="sepal_width",data = data)

axes1 = plt.subplot2grid(
    (7,1),(0,0), rowspan = 2, colspan = 1)
graph()

axes2 = plt.subplot2grid(
    (7,1),(2,0), rowspan = 2, colspan=1)
graph()

axes3 = plt.subplot2grid(
    (7,1),(4,0), rowspan = 2, colspan = 1)
graph()

# %% [markdown]
# **MULTIPLE PLOTS**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

plot = sns.FacetGrid(data, col ="species")
plot.map(plt.plot, "sepal_width")

plt.show()

# %% [markdown]
# Method 2: Using PairGrid() method
#
#
#
# Subplot grid for plotting pairwise relationships in a dataset.
# This class maps each variable in a dataset onto a column and row in a grid of multiple axes. Different axes-level plotting functions can be used to draw bivariate plots in the upper and lower triangles, and the marginal distribution of each variable can be shown on the diagonal.
# It can also represent an additional level of conventionalization with the hue parameter, which plots different subsets of data in different colors. This uses color to resolve elements on a third dimension, but only draws subsets on top of each other and will not tailor the hue parameter for the specific visualization the way that axes-level functions that accept hue will.
#
#
# Syntax:
#
#
#
# seaborn.PairGrid( data, \*\*kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("flights")

plot = sns.PairGrid(data)
plot.map(plt.plot)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.relplot(x='sepal_width', y='species', data = data)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.scatterplot(x='sepal_length',y='sepal_width', data=data)
plt.show()

# %%
#lineplot

import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.lineplot(x='sepal_length',y='species', data = data)

plt.show()

# %%
#barplot
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.barplot(x='species', y='sepal_length', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('iris')

sns.countplot(x='species', data = data)

plt.show()

# %%
#boxplot
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('iris')

sns.boxplot(x='species',y='sepal_width',data=data)
plt.show()
