# %%
import pandas as pd
coffee = pd.read_feather('https://assets.datacamp.com/production/repositories/5975/datasets/17ec88d6bf920ba7f159298d6acba118a907dacf/coffee_ratings_full.feather')
spotify = pd.read_feather('https://assets.datacamp.com/production/repositories/5975/datasets/18d07c39535b900b64dc145985d9e8dfbf2ca498/spotify_2000_2020.feather')
attrition = pd.read_feather('https://assets.datacamp.com/production/repositories/5975/datasets/3ca1b1a6e25d960f872dcee7cde666d57680bae0/attrition.feather')

# %%
cup = coffee[['total_cup_points','flavor']]

# %%
cup_samp =cup.sample(n=10)

# %%
cup_samp.sample(n=5)
# Out:
#       total_cup_points  flavor
# 562              82.83    7.67
# 1074             80.50    7.17
# 228              84.17    7.75
# 815              81.92    7.50
# 965              81.25    7.17

# %%
coffee.to_csv('/Users/ecuerbo/python/pyprac/data/coffee.csv')
spotify.to_csv('/Users/ecuerbo/python/pyprac/data/spotify.csv')
attrition.to_csv('/Users/ecuerbo/python/pyprac/data/attrition.csv')

# %%
randoms = np.random.beta(a=2, b=2, size=5000)
randoms
# Out:
# array([0.46274764, 0.82438755, 0.45637999, ..., 0.23425979, 0.69502727,
#        0.24529241])

# %%
import matplotlib.pyplot as plt
plt.hist(randoms, bins=np.arange(0,1,0.05));

# %%
np.random.seed(20000229)
np.random.normal(loc=2, scale=1.5, size=2)
# Out:
# array([-0.59030264,  1.87821258])

# %%
np.random.normal(loc=2, scale=1.5, size=2)
# Out:
# array([2.52619561, 4.9684949 ])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/ecuerbo/python/pyprac/data/coffee.csv')
# Out:
#    Unnamed: 0  total_cup_points  species                     owner  \
# 0           0             90.58  Arabica                 metad plc
# 1           1             89.92  Arabica                 metad plc
# 2           2             89.75  Arabica  grounds for health admin
# 3           3             89.00  Arabica       yidnekachew dabessa
# 4           4             88.83  Arabica                 metad plc
#
#   country_of_origin                                 farm_name lot_number  \
# 0          Ethiopia                                 metad plc        NaN
# 1          Ethiopia                                 metad plc        NaN
# 2         Guatemala  san marcos barrancas "san cristobal cuch        NaN
# 3          Ethiopia     yidnekachew dabessa coffee plantation        NaN
# 4          Ethiopia                                 metad plc        NaN
#
#         mill ico_number                                company  ...  color  \
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#simple random sampling
df.sample(n=5, random_state=19000113)
# Out:
#      total_cup_points  species                           owner  \
# 437             83.25  Arabica  exportadora de cafe condor s.a
# 285             83.83  Arabica                 ipanema coffees
# 784             82.08  Arabica                   cafe politico
# 648             82.58  Arabica  exportadora de cafe condor s.a
# 155             84.58  Arabica  exportadora de cafe condor s.a
#
#     country_of_origin          farm_name lot_number  \
# 437          Colombia                NaN        NaN
# 285            Brazil  fazenda rio verde        NaN
# 784          Colombia                NaN        NaN
# 648          Colombia                NaN        NaN
# 155          Colombia            various        NaN
#
#                                       mill     ico_number  \
# 437  trilladora bonanza - armenia quindioa      3-68-0205
# 285                        ipanema coffees  002/4177/0121
# 784                                    NaN      3-59-1656
# ...

# %%
#systematic sampling
sample_size= 5
pop_size=len(df)
interval = pop_size//sample_size
df.iloc[::interval].head()
# Out:
#       total_cup_points  species                             owner  \
# 0                90.58  Arabica                         metad plc
# 267              83.92  Arabica  federacion nacional de cafeteros
# 534              82.92  Arabica      consejo salvadoreño del café
# 801              82.00  Arabica            lin, che-hao krude 林哲豪
# 1068             80.50  Arabica          cqi taiwan icp cqi台灣合作夥伴
#
#      country_of_origin                                     farm_name  \
# 0             Ethiopia                                     metad plc
# 267           Colombia                                           NaN
# 534        El Salvador                                santa josefita
# 801             Taiwan  you siang coffee farmtainan, taiwan 台灣台南優香咖啡
# 1068            Taiwan                                           王秋金
#
#      lot_number                                          mill  ico_number  \
# 0           NaN                                     metad plc   2014/2015
# ...

# %%
import matplotlib.pyplot as plt
df_with_id = df.reset_index()
df_with_id.plot(x='index', y="aftertaste", kind='scatter');

# %%
shuffled = df.sample(frac=1)
shuffled = shuffled.reset_index(drop=True).reset_index()
shuffled.plot(x='index', y="aftertaste", kind='scatter');

# %%
#stratified and weighted random sampling
top_counted_countries = df['country_of_origin'].value_counts().head(6).index.to_list()
top_counted_subset = df['country_of_origin'].isin(top_counted_countries)
coffee_ratings_top = df[top_counted_subset]
# Out:
#       total_cup_points  species                          owner  \
# 2                89.75  Arabica       grounds for health admin
# 5                88.83  Arabica                      ji-ae ahn
# 13               87.92  Arabica       grounds for health admin
# 22               87.17  Arabica          roberto licona franco
# 25               86.92  Arabica                       nucoffee
# ...                ...      ...                            ...
# 1300             71.00  Arabica  ricardo aaron sampieri marini
# 1301             70.75  Arabica                   kurt kappeli
# 1302             70.67  Arabica         volcafe ltda. - brasil
# 1306             68.33  Arabica       juan carlos garcia lopez
# 1309             59.83  Arabica      juan luis alvarado romero
#
#            country_of_origin                                 farm_name  \
# 2                  Guatemala  san marcos barrancas "san cristobal cuch
# ...

# %%
coffee_ratings_samp = coffee_ratings_top.sample(frac=0.1, random_state=2021)
coffee_ratings_samp['country_of_origin'].value_counts(normalize=True)
# Out:
# Mexico                    0.250000
# Guatemala                 0.204545
# Colombia                  0.181818
# Brazil                    0.181818
# United States (Hawaii)    0.102273
# Taiwan                    0.079545
# Name: country_of_origin, dtype: float64

# %%
#population proportions
coffee_ratings_top['country_of_origin'].value_counts(normalize=True).head(6)
# Out:
# Mexico                    0.268182
# Colombia                  0.207955
# Guatemala                 0.205682
# Brazil                    0.150000
# Taiwan                    0.085227
# United States (Hawaii)    0.082955
# Name: country_of_origin, dtype: float64

# %%
#proportional stratified sampling
coffee_ratings_strat = coffee_ratings_top.groupby("country_of_origin")\
    .sample(frac=0.1, random_state=2021)
coffee_ratings_strat['country_of_origin'].value_counts(normalize=True).head(6)
# Out:
# Mexico                    0.272727
# Colombia                  0.204545
# Guatemala                 0.204545
# Brazil                    0.147727
# Taiwan                    0.090909
# United States (Hawaii)    0.079545
# Name: country_of_origin, dtype: float64

# %%
#equal counts stratified sampling
coffee_ratings_eq = coffee_ratings_top.groupby("country_of_origin")\
    .sample(n=15, random_state=2021)
coffee_ratings_eq['country_of_origin'].value_counts(normalize=True).head(6)
# Out:
# Brazil                    0.166667
# Colombia                  0.166667
# Guatemala                 0.166667
# Mexico                    0.166667
# Taiwan                    0.166667
# United States (Hawaii)    0.166667
# Name: country_of_origin, dtype: float64

# %%
#weighted random sampling
import numpy as np
coffee_ratings_weight =coffee_ratings_top
condition = coffee_ratings_weight['country_of_origin'] == "Taiwan"
coffee_ratings_weight['weight'] = np.where(condition, 2,1)
# Out:
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_11085/3449940526.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee_ratings_weight['weight'] = np.where(condition, 2,1)

# %%
coffee_ratings_weight['country_of_origin'].value_counts(normalize=True).head(6)
# Out:
# Mexico                    0.268182
# Colombia                  0.207955
# Guatemala                 0.205682
# Brazil                    0.150000
# Taiwan                    0.085227
# United States (Hawaii)    0.082955
# Name: country_of_origin, dtype: float64

# %%
coffee_ratings_top.shape
# Out:
# (880, 44)

# %%
#simple random sampling
df_srs = coffee_ratings_top.sample(frac=1/3, random_state=2021)
df_srs.shape
# Out:
# (293, 44)

# %%
#stratified sampling
df_str = coffee_ratings_top.groupby('country_of_origin').sample(frac=1/3, random_state=2021)
df_str.shape
# Out:
# (293, 44)

# %%
mean_cup_points_1000 = []
for i in range(1000):
    mean_cup_points_1000.append(df.sample(n=30)['total_cup_points'].mean())
import matplotlib.pyplot as plt
plt.hist(mean_cup_points_1000, bins=30);
