# %% [markdown]
# ### Loading Data into Pandas

# %%
import pandas as pd
df = pd.read_csv("pokemon/pokemon.csv")

#df.head()

# %% [markdown]
# ### Reading data in Pandas

# %%
#read headers
df.columns

#read each column
print(df['Name'][0:5])

#read each row
print(df.iloc[1])

df.iloc[0:4][0:5]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Name, dtype: object
# #                  2
# Name         Ivysaur
# Type 1         Grass
# Type 2        Poison
# Total            405
# HP                60
# Attack            62
# Defense           63
# Sp. Atk           80
# Sp. Def           80
# Speed             60
# Stage              2
# Legendary      False
# Name: 1, dtype: object
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False

# %%
for index, row in df.iterrows():
    print(index, row['HP'])
# Out:
# 0 45
# 1 60
# 2 80
# 3 39
# 4 58
# 5 78
# 6 44
# 7 59
# 8 79
# 9 45
# 10 50
# 11 60
# 12 40
# 13 45
# 14 65
# 15 40
# 16 63
# 17 83
# 18 30
# 19 55
# 20 40
# 21 65
# 22 35
# 23 60
# 24 35
# 25 60
# 26 50
# 27 75
# 28 55
# 29 70
# 30 90
# 31 46
# 32 61
# 33 81
# 34 70
# 35 95
# 36 38
# 37 73
# 38 115
# 39 140
# 40 40
# 41 75
# 42 45
# 43 60
# 44 75
# 45 35
# 46 60
# 47 60
# 48 70
# 49 10
# 50 35
# 51 40
# 52 65
# 53 50
# 54 80
# 55 40
# 56 65
# 57 55
# 58 90
# 59 40
# 60 65
# 61 90
# 62 25
# 63 40
# 64 55
# 65 70
# 66 80
# 67 90
# 68 50
# 69 65
# 70 80
# 71 40
# 72 80
# 73 40
# 74 55
# 75 80
# 76 50
# 77 65
# 78 90
# 79 95
# 80 25
# 81 50
# 82 52
# 83 35
# 84 60
# 85 65
# 86 90
# 87 80
# 88 105
# 89 30
# 90 50
# 91 30
# 92 45
# 93 60
# 94 35
# 95 60
# 96 85
# 97 30
# 98 55
# 99 40
# 100 60
# 101 60
# 102 95
# 103 50
# 104 60
# 105 50
# 106 50
# 107 90
# 108 40
# 109 65
# 110 80
# 111 105
# 112 250
# 113 65
# 114 105
# 115 30
# 116 55
# 117 45
# 118 80
# 119 30
# 120 60
# 121 40
# ...

# %%
#using loc
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #        Name Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur  Grass   Poison    318  45      49       49       65
# 1      2     Ivysaur  Grass   Poison    405  60      62       63       80
# 2      3    Venusaur  Grass   Poison    525  80      82       83      100
# 42    43      Oddish  Grass   Poison    320  45      50       55       75
# 43    44       Gloom  Grass   Poison    395  60      65       70       85
# 44    45   Vileplume  Grass   Poison    490  75      80       85      110
# 68    69  Bellsprout  Grass   Poison    300  50      75       35       70
# 69    70  Weepinbell  Grass   Poison    390  65      90       50       85
# 70    71  Victreebel  Grass   Poison    490  80     105       65      100
# 101  102   Exeggcute  Grass  Psychic    325  60      40       80       60
# 102  103   Exeggutor  Grass  Psychic    520  95      95       85      125
# 113  114     Tangela  Grass      NaN    435  65      55      115      100
#
# ...

# %%
#read specific location
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
### Sorting/Describing Data
df.sort_values(['Type 1','HP'], ascending=[1,0])
# Out:
#        #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 48    49    Venomoth    Bug  Poison    450  70      65       60       90
# 122  123     Scyther    Bug  Flying    500  70     110       80       55
# 14    15    Beedrill    Bug  Poison    395  65      90       40       45
# 126  127      Pinsir    Bug     NaN    500  65     125      100       55
# 11    12  Butterfree    Bug  Flying    395  60      45       50       90
# ..   ...         ...    ...     ...    ...  ..     ...      ...      ...
# 89    90    Shellder  Water     NaN    305  30      65      100       45
# 97    98      Krabby  Water     NaN    325  30     105       90       25
# 115  116      Horsea  Water     NaN    295  30      40       70       70
# 119  120      Staryu  Water     NaN    340  30      45       55       70
# 128  129    Magikarp  Water     NaN    200  20      10       55       15
#
#      Sp. Def  Speed  Stage  Legendary
# 48        75     90      2      False
# ...

# %% [markdown]
# ### Making changes to the data

# %%
#df['Total'] = df['HP'] + df['Attack'] +df['Sp. Atk'] + df['Defense'] +df['Sp. Def'] + df['Speed']
#df.drop(columns=['Total'], inplace=True)
df['Total'] = df.iloc[:,4:10].sum(axis=1)

cols = list(df.columns.values)

df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #        Name Type 1  Type 2  Legendary  Total  HP  Attack  Defense  \
# 0  1   Bulbasaur  Grass  Poison      False    591  45      49       49
# 1  2     Ivysaur  Grass  Poison      False    750  60      62       63
# 2  3    Venusaur  Grass  Poison      False    970  80      82       83
# 3  4  Charmander   Fire     NaN      False    553  39      52       43
# 4  5  Charmeleon   Fire     NaN      False    730  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Stage
# 0       65       65     45      1
# 1       80       80     60      2
# 2      100      100     80      3
# 3       60       50     65      1
# 4       80       65     80      2

# %% [markdown]
# ### Saving our data

# %%
df.to_csv("modified.csv", index=False)
#df.to_excel('modified.xlsx', index=False)

#df.to_csv('modified.txt', index= False, sep='\t')

# %% [markdown]
# ### Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2']=='Poison') &(df['HP'] > 70)]

#new_df.to_csv('modif.csv')

new_df.reset_index(drop=True, inplace=True)
new_df.head()
# Out:
#     #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1   2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2   3   Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  43     Oddish  Grass  Poison    320  45      50       55       75       65
# 4  44      Gloom  Grass  Poison    395  60      65       70       85       75
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     30      1      False
# 4     40      2      False

# %%
#select only pokemons with "saur"
df.loc[df['Name'].str.contains('saur')]
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False

# %%
#select only pokemons with "Char
df.loc[df['Name'].str.contains('Char')]
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
# 5  6   Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Stage  Legendary
# 3     65      1      False
# 4     80      2      False
# 5    100      3      False

# %%
#select only pokemons with "mew"
df.loc[df['Name'].str.contains('ew')]
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 26    27  Sandshrew   Ground    NaN    300   50      75       85       20
# 86    87    Dewgong    Water    Ice    475   90      70       80       70
# 149  150     Mewtwo  Psychic    NaN    680  106     110       90      154
# 150  151        Mew  Psychic    NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 26        30     40      1      False
# 86        95     70      2      False
# 149       90    130      1       True
# 150      100    100      1      False

# %% [markdown]
# ### Conditional Changes

# %%
#df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
df.loc[df['Total']>500,['Generation','Legendary']] = 'Test value'
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage   Legendary  Generation
# ...

# %%
#change multiple columns with multiple values
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage Legendary Generation
# ...

# %% [markdown]
# ### Aggregate Statistics (Groupby)

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=True)
# Out:
#                    #  Legendary       Total         HP      Attack  \
# Type 1
# Ghost      93.000000   0.000000  715.000000  45.000000   50.000000
# Normal     71.727273   0.000000  691.500000  78.681818   67.727273
# Bug        42.916667   0.000000  615.416667  55.416667   63.750000
# Psychic   101.000000   0.125000  847.250000  63.875000   60.125000
# Fairy      35.500000   0.000000  758.500000  82.500000   57.500000
# Fighting   75.285714   0.000000  758.142857  63.571429  102.857143
# Fire       64.166667   0.083333  827.166667  63.833333   83.916667
# Electric   91.111111   0.111111  790.000000  54.444444   62.000000
# Poison     51.071429   0.000000  708.214286  64.500000   74.428571
# Ice       134.000000   0.500000  945.000000  77.500000   67.500000
# Dragon    148.000000   0.000000  813.333333  64.333333   94.000000
# Grass      55.583333   0.000000  766.750000  65.000000   70.666667
# Water      85.928571   0.000000  754.714286  64.535714   70.250000
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending=True)
# Out:
#                    #  Legendary       Total         HP      Attack  \
# Type 1
# Ghost      93.000000   0.000000  715.000000  45.000000   50.000000
# Fairy      35.500000   0.000000  758.500000  82.500000   57.500000
# Psychic   101.000000   0.125000  847.250000  63.875000   60.125000
# Electric   91.111111   0.111111  790.000000  54.444444   62.000000
# Bug        42.916667   0.000000  615.416667  55.416667   63.750000
# Ice       134.000000   0.500000  945.000000  77.500000   67.500000
# Normal     71.727273   0.000000  691.500000  78.681818   67.727273
# Water      85.928571   0.000000  754.714286  64.535714   70.250000
# Grass      55.583333   0.000000  766.750000  65.000000   70.666667
# Poison     51.071429   0.000000  708.214286  64.500000   74.428571
# Ground     73.500000   0.000000  690.625000  58.125000   81.875000
# Rock      113.333333   0.000000  782.777778  53.888889   82.222222
# Fire       64.166667   0.083333  827.166667  63.833333   83.916667
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug         12
# Dragon       3
# Electric     9
# Fairy        2
# Fighting     7
# Fire        12
# Ghost        3
# Grass       12
# Ground       8
# Ice          2
# Normal      22
# Poison      14
# Psychic      8
# Rock         9
# Water       28
# Name: count, dtype: int64

# %% [markdown]
# ### Working with Large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
