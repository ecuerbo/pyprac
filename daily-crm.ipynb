# %%
import pandas as pd

daily=pd.read_csv('data/daily-crm.csv')
daily.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_7291/1914942240.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 daily=pd.read_csv('data/daily-crm.csv',Parse_DateS=True)
#       4 daily.head()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'Parse_DateS'

# %%
imp = ['xrf','crm','ni','fe','alu','dt']
df = daily[imp]
df.head()
# Out:
#    xrf  crm    ni    fe   alu                dt
# 0    4  S11  1.02  8.79  1.17  12/08/2021 16:09
# 1    4  S11  1.02  8.80  1.17  12/08/2021 16:19
# 2    4  S11  1.02  8.80  1.17  12/08/2021 16:29
# 3    4  S11  1.01  8.73  1.15  02/03/2022 14:20
# 4    4  S11  1.02  8.79  1.16  02/03/2022 14:25

# %%
s1_out = monitored[(monitored['crm']=='S1') & (monitored['fe']>49.5)]
s1_out.head()
# Out:
#      crm    ni     fe    alu                dt
# 2142  S1  0.62  49.64  10.22   06/03/2022 9:32
# 2184  S1  0.63  49.84  10.47  06/04/2022 14:22
# 2196  S1  0.63  49.68  10.20   06/05/2022 2:46
# 2210  S1  0.63  49.53   9.88   06/07/2022 6:14
# 2258  S1  0.63  49.58  10.37  06/03/2022 11:42

# %%
s1_out.shape
# Out:
# (10, 5)

# %%
daily['fe_over_ni'] = daily['fe']/daily['ni']
daily.head()
# Out:
#    crm    ni    fe      co   alu    sil       p       s    mag    cal    chr  \
# 0  S11  1.02  8.79  0.0203  1.17  45.24  0.0031  0.0020  27.54  0.641  0.642
# 1  S11  1.02  8.80  0.0196  1.17  45.18  0.0028  0.0021  27.62  0.635  0.648
# 2  S11  1.02  8.80  0.0190  1.17  45.21  0.0028  0.0020  27.55  0.631  0.642
# 3  S11  1.01  8.73  0.0202  1.15  44.59  0.0028  0.0026  27.13  0.663  0.651
# 4  S11  1.02  8.79  0.0202  1.16  45.09  0.0032  0.0025  26.82  0.671  0.657
#
#      man  tit                dt  xrf note  fe_over_ni
# 0  0.183  NaN  12/08/2021 16:09    4  NaN    8.617647
# 1  0.182  NaN  12/08/2021 16:19    4  NaN    8.627451
# 2  0.183  NaN  12/08/2021 16:29    4  NaN    8.627451
# 3  0.183  NaN  02/03/2022 14:20    4  NaN    8.643564
# 4  0.185  NaN  02/03/2022 14:25    4  NaN    8.617647

# %%
sel = daily[imp]
sel.head()
# Out:
#    crm    ni    fe   alu                dt
# 0  S11  1.02  8.79  1.17  12/08/2021 16:09
# 1  S11  1.02  8.80  1.17  12/08/2021 16:19
# 2  S11  1.02  8.80  1.17  12/08/2021 16:29
# 3  S11  1.01  8.73  1.15  02/03/2022 14:20
# 4  S11  1.02  8.79  1.16  02/03/2022 14:25

# %%
sel.dt.max()
sel.dt.min()
# Out:
# '02/03/2022 14:20'

# %%
import numpy as np
df.groupby(['xrf','crm'])['fe'].agg([min,max,np.mean,np.median])
# Out:
#            min    max       mean  median
# xrf crm
# 2   S1   40.50  49.84  48.419119  48.430
#     S11   8.14   8.60   8.324435   8.310
#     S12  13.31  14.13  13.659237  13.610
#     S1x  45.15  45.15  45.150000  45.150
#     S2   46.59  52.71  51.408750  51.430
#     S2x  41.77  48.45  45.110000  45.110
# 3   S1   46.89  49.10  48.324693  48.360
#     S11   8.12   8.39   8.276822   8.290
#     S12  13.76  14.22  13.974250  13.975
#     S2   50.23  52.06  51.179012  51.190
# 4   S1   46.53  49.45  48.669536  48.660
#     S11   8.43   8.91   8.812798   8.840
#     S12  13.73  14.22  13.983659  14.000
#     S2   48.93  52.81  51.950274  52.110

# %%
daily.head()
# Out:
#    crm    ni    fe      co   alu    sil       p       s    mag    cal    chr  \
# 0  S11  1.02  8.79  0.0203  1.17  45.24  0.0031  0.0020  27.54  0.641  0.642
# 1  S11  1.02  8.80  0.0196  1.17  45.18  0.0028  0.0021  27.62  0.635  0.648
# 2  S11  1.02  8.80  0.0190  1.17  45.21  0.0028  0.0020  27.55  0.631  0.642
# 3  S11  1.01  8.73  0.0202  1.15  44.59  0.0028  0.0026  27.13  0.663  0.651
# 4  S11  1.02  8.79  0.0202  1.16  45.09  0.0032  0.0025  26.82  0.671  0.657
#
#      man  tit                dt  xrf note  fe_over_ni
# 0  0.183  NaN  12/08/2021 16:09    4  NaN    8.617647
# 1  0.182  NaN  12/08/2021 16:19    4  NaN    8.627451
# 2  0.183  NaN  12/08/2021 16:29    4  NaN    8.627451
# 3  0.183  NaN  02/03/2022 14:20    4  NaN    8.643564
# 4  0.185  NaN  02/03/2022 14:25    4  NaN    8.617647

# %%
 concern = daily[imp]

# %%
concern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5055 entries, 0 to 5054
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   xrf     5055 non-null   int64
#  1   crm     5055 non-null   object
#  2   ni      5055 non-null   float64
#  3   fe      5055 non-null   float64
#  4   alu     5055 non-null   float64
#  5   dt      5055 non-null   object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 237.1+ KB

# %%
concern.describe()
# Out:
#                xrf           ni           fe          alu
# count  5055.000000  5055.000000  5055.000000  5055.000000
# mean      2.842334     0.718730    44.266580     7.327736
# std       0.747948     0.204136    13.819946     2.927562
# min       2.000000     0.510000     8.120000     0.000000
# 25%       2.000000     0.630000    48.170000     6.610000
# 50%       3.000000     0.640000    48.750000     6.930000
# 75%       3.000000     0.660000    51.275000     9.970000
# max       4.000000     1.420000    52.810000    11.270000

# %%
#second attempt at analyzing qc data
import pandas as pd

daily = pd.read_csv("data/daily.csv")
daily.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_1071/1465081794.py in <module>
#       4 daily = pd.read_csv("data/daily.csv")
#       5 daily.head()
# ----> 6 daily[:,:15]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(None, 15, None))' is an invalid key

# %%
daily = daily.iloc[:,:15]
daily.describe()
# Out:
#                 ni           fe          alu          sil            s  \
# count  7072.000000  7072.000000  7072.000000  7072.000000  7072.000000
# mean      0.732764    45.772598     7.117097     6.106058     0.136198
# std       0.197620    12.619706     2.917580    11.956013     0.050307
# min       0.510000     8.120000     0.000000     0.000000     0.000000
# 25%       0.630000    48.320000     6.510000     1.710000     0.130100
# 50%       0.650000    49.150000     6.870000     1.840000     0.151500
# 75%       0.660000    51.470000     9.850000     2.120000     0.161900
# max       1.420000    55.070000    11.450000    46.430000     0.191900
#
#                mag          chr          man          xrf
# count  7071.000000  6910.000000  6910.000000  7072.000000
# mean      3.899803     3.782400     0.867964     2.856900
# std       8.310222     1.180041     0.286708     0.757295
# min       0.000000     0.641000     0.158000     2.000000
# 25%       0.760000     3.652000     0.790000     2.000000
# 50%       0.940000     3.854000     0.933000     3.000000
# 75%       1.110000     4.693000     0.966000     3.000000
# max      30.690000     5.260000     1.466000     4.000000

# %%
imp = ['xrf','sample','ni','fe','alu','date']
con=daily[imp]

# %%
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7074 entries, 0 to 7073
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   xrf     7072 non-null   float64
#  1   sample  7072 non-null   object
#  2   ni      7072 non-null   float64
#  3   fe      7072 non-null   float64
#  4   alu     7072 non-null   float64
#  5   date    7072 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 331.7+ KB
