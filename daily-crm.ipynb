# %%
import pandas as pd

daily=pd.read_csv('data/daily-crm.csv')
daily.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_7291/1914942240.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 daily=pd.read_csv('data/daily-crm.csv',Parse_DateS=True)
#       4 daily.head()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'Parse_DateS'

# %%
imp = ['xrf','crm','ni','fe','alu','dt']
df = daily[imp]
df.head()
# Out:
#    xrf  crm    ni    fe   alu                dt
# 0    4  S11  1.02  8.79  1.17  12/08/2021 16:09
# 1    4  S11  1.02  8.80  1.17  12/08/2021 16:19
# 2    4  S11  1.02  8.80  1.17  12/08/2021 16:29
# 3    4  S11  1.01  8.73  1.15  02/03/2022 14:20
# 4    4  S11  1.02  8.79  1.16  02/03/2022 14:25

# %%
s1_out = monitored[(monitored['crm']=='S1') & (monitored['fe']>49.5)]
s1_out.head()
# Out:
#      crm    ni     fe    alu                dt
# 2142  S1  0.62  49.64  10.22   06/03/2022 9:32
# 2184  S1  0.63  49.84  10.47  06/04/2022 14:22
# 2196  S1  0.63  49.68  10.20   06/05/2022 2:46
# 2210  S1  0.63  49.53   9.88   06/07/2022 6:14
# 2258  S1  0.63  49.58  10.37  06/03/2022 11:42

# %%
s1_out.shape
# Out:
# (10, 5)

# %%
daily['fe_over_ni'] = daily['fe']/daily['ni']
daily.head()
# Out:
#    crm    ni    fe      co   alu    sil       p       s    mag    cal    chr  \
# 0  S11  1.02  8.79  0.0203  1.17  45.24  0.0031  0.0020  27.54  0.641  0.642
# 1  S11  1.02  8.80  0.0196  1.17  45.18  0.0028  0.0021  27.62  0.635  0.648
# 2  S11  1.02  8.80  0.0190  1.17  45.21  0.0028  0.0020  27.55  0.631  0.642
# 3  S11  1.01  8.73  0.0202  1.15  44.59  0.0028  0.0026  27.13  0.663  0.651
# 4  S11  1.02  8.79  0.0202  1.16  45.09  0.0032  0.0025  26.82  0.671  0.657
#
#      man  tit                dt  xrf note  fe_over_ni
# 0  0.183  NaN  12/08/2021 16:09    4  NaN    8.617647
# 1  0.182  NaN  12/08/2021 16:19    4  NaN    8.627451
# 2  0.183  NaN  12/08/2021 16:29    4  NaN    8.627451
# 3  0.183  NaN  02/03/2022 14:20    4  NaN    8.643564
# 4  0.185  NaN  02/03/2022 14:25    4  NaN    8.617647

# %%
sel = daily[imp]
sel.head()
# Out:
#    crm    ni    fe   alu                dt
# 0  S11  1.02  8.79  1.17  12/08/2021 16:09
# 1  S11  1.02  8.80  1.17  12/08/2021 16:19
# 2  S11  1.02  8.80  1.17  12/08/2021 16:29
# 3  S11  1.01  8.73  1.15  02/03/2022 14:20
# 4  S11  1.02  8.79  1.16  02/03/2022 14:25

# %%
sel.dt.max()
sel.dt.min()
# Out:
# '02/03/2022 14:20'

# %%
import numpy as np
df.groupby(['xrf','crm'])['fe'].agg([min,max,np.mean,np.median])
# Out:
#            min    max       mean  median
# xrf crm
# 2   S1   40.50  49.84  48.419119  48.430
#     S11   8.14   8.60   8.324435   8.310
#     S12  13.31  14.13  13.659237  13.610
#     S1x  45.15  45.15  45.150000  45.150
#     S2   46.59  52.71  51.408750  51.430
#     S2x  41.77  48.45  45.110000  45.110
# 3   S1   46.89  49.10  48.324693  48.360
#     S11   8.12   8.39   8.276822   8.290
#     S12  13.76  14.22  13.974250  13.975
#     S2   50.23  52.06  51.179012  51.190
# 4   S1   46.53  49.45  48.669536  48.660
#     S11   8.43   8.91   8.812798   8.840
#     S12  13.73  14.22  13.983659  14.000
#     S2   48.93  52.81  51.950274  52.110
