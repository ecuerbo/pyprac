# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
#load our first page
r = requests.get("https://keithgalli.github.io/web-scraping/example.html")

#convert to bs object
soup=bs(r.content)

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
#start scraping us Beautiful Soup
#find and find_all
first_header =soup.find("h2")
first_header

headers = soup.find_all("h2")
headers
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
first_header =soup.find_all(["h2", "h1"])
first_header
# Out:
# [<h1>HTML Webpage</h1>, <h2>A Header</h2>, <h2>Another header</h2>]

# %%
#pass an attribute to the find/find_all function
paragraph = soup.find_all("p", attrs={"id":"paragraph-id"})
paragraph
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %%
#nest find/find_all calls
body = soup.find("body")
div = body.find("div")
header =div.find("h1")
header
# Out:
# <h1>HTML Webpage</h1>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
#search specific strings in ur find/find_all calls
import re
paragraphs = soup.find_all("p", string=re.compile("Some"))
paragraphs
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
headers = soup.find_all("h2", string=re.compile("(H|h)eader"))
headers
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %% [markdown]
# **select (CSS Selector)**

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
content = soup.select("div p")
content
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>]

# %%
paragraphs = soup.select("h2 ~ p")
paragraphs
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
bold_text = soup.select("p#paragraph-id b")
bold_text
# Out:
# [<b>Some bold text</b>]

# %%
paragraphs = soup.select("body > p")
paragraphs
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
for paragraph in paragraphs:
    print(paragraph.select("i"))
# Out:
# [<i>Some italicized text</i>]
# []

# %%
#GEt different properties of HTML

# %%
header = soup.find("h2")
header
# Out:
# <h2>A Header</h2>

# %%
div = soup.find("div")
print(div.prettify())
# Out:
# <div align="middle">
#  <h1>
#   HTML Webpage
#  </h1>
#  <p>
#   Link to more interesting example:
#   <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#    keithgalli.github.io/web-scraping/webpage.html
#   </a>
#  </p>
# </div>

# %%
#Get a specific property from an element
link = soup.find("a")
link['href']
# Out:
# 'https://keithgalli.github.io/web-scraping/webpage.html'

# %%
paragraphs = soup.select("p#paragraph.id")
paragraphs[0]['id']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/g6/qw3t2lbx7x91r1mfyp6k77k00000gn/T/ipykernel_4657/642523153.py in <module>
#       1 paragraphs = soup.select("p#paragraph.id")
# ----> 2 paragraphs[0]['id']
#
# IndexError: list index out of range

# %%
#code navigation
soup.body.div
# Out:
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>

# %%
#parent, sibling, child

# %%
soup.body.find('div')
# Out:
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>

# %%
soup.body.find('div').find_next_siblings()
# Out:
# [<h2>A Header</h2>,
#  <p><i>Some italicized text</i></p>,
#  <h2>Another header</h2>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
r = requests.get("https://keithgalli.github.io/web-scraping/webpage.html")

#convert to bs object
webpage=bs(r.content)

print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
#    Hi, my name is Keith and I am a YouTuber who focuses on content related to programming, data science, and machine learning!
#   </p>
#   <p>
#    Here is a link to my channel:
#    <a href="https://www.youtube.com/kgmit">
#     youtube.com/kgmit
#    </a>
#   </p>
#   <p>
#    I grew up in the great state of New Hampshire here in the USA. From an early age I always loved math. Around my senior year of high school, my brother first introduced me to programming. I found it a creative way to apply the same type of logical thinking skills that I enjoyed with math. This influenced me to study computer science in college and ultimately create a YouTube channel to share some things that I have learned along the way.
#   </p>
#   <h3>
#    Hobbies
#   </h3>
#   <p>
#    Believe it or not, I don't code 24/7. I love doing all sorts of active things. I like to play ice hockey &amp; table tennis as well as run, hike, skateboard, and snowboard. In addition to sports, I am a board game enthusiast. The two that I've been playing the most recently are
#    <i>
#     Settlers of Catan
#    </i>
#    and
#    <i>
#     Othello
#    </i>
#    .
#   </p>
#   <h3>
#    Fun Facts
#   </h3>
#   <ul class="fun-facts">
#    <li>
#     Owned my dream car in high school
#     <a href="#footer">
#      <sup>
#       1
#      </sup>
#     </a>
#    </li>
#    <li>
#     Middle name is Ronald
#    </li>
#    <li>
#     Never had been on a plane until college
#    </li>
#    <li>
#     Dunkin Donuts coffee is better than Starbucks
#    </li>
#    <li>
#     A favorite book series of mine is
#     <i>
#      Ender's Game
#     </i>
#    </li>
#    <li>
#     Current video game of choice is
#     <i>
#      Rocket League
#     </i>
#    </li>
#    <li>
#     The band that I've seen the most times live is the
#     <i>
#      Zac Brown Band
#     </i>
#    </li>
#   </ul>
#   <h2>
#    Social Media
#   </h2>
#   I encourage you to check out my content on all social media platforms
#   <br/>
#   <ul class="socials">
#    <li class="social instagram">
#     <b>
#      Instagram:
#     </b>
#     <a href="https://www.instagram.com/keithgalli/">
#      https://www.instagram.com/keithgalli/
#     </a>
#    </li>
#    <li class="social twitter">
#     <b>
#      Twitter:
#     </b>
#     <a href="https://twitter.com/keithgalli">
#      https://twitter.com/keithgalli
#     </a>
#    </li>
#    <li class="social linkedin">
#     <b>
#      LinkedIn:
#     </b>
#     <a href="https://www.linkedin.com/in/keithgalli/">
#      https://www.linkedin.com/in/keithgalli/
#     </a>
#    </li>
#    <li class="social tiktok">
#     <b>
#      TikTok:
#     </b>
#     <a href="https://www.tiktok.com/@keithgalli">
#      https://www.tiktok.com/@keithgalli
#     </a>
#    </li>
#   </ul>
#   <h2>
#    Photos
#   </h2>
#   Here are a few photos from a trip to italy I took last year
#   <div class="row">
#    <div class="column">
#     <img alt="Lake Como" src="images/italy/lake_como.jpg" style="height:100%"/>
#    </div>
#    <div class="column">
#     <img alt="Pontevecchio, Florence" src="images/italy/pontevecchio.jpg" style="height:100%"/>
#    </div>
#    <div class="column">
#     <img alt="Riomaggiore, Cinque de Terre" src="images/italy/riomaggiore.jpg" style="height:100%"/>
#    </div>
#   </div>
#   <div>
#   </div>
#   <h2>
#    Table
#   </h2>
#   My MIT hockey stats :)
#   <br/>
#   <table class="hockey-stats">
#    <thead>
#     <tr>
#      <th class="season" data-sort="">
#       S
#      </th>
#      <th class="team" data-sort="team">
#       Team
#      </th>
#      <th class="league" data-sort="league">
#       League
#      </th>
#      <th class="regular gp" data-sort="gp">
#       GP
#      </th>
#      <th class="regular g" data-sort="g">
#       G
#      </th>
#      <th class="regular a" data-sort="a">
#       A
#      </th>
#      <th class="regular tp" data-sort="tp">
#       TP
#      </th>
#      <th class="regular pim" data-sort="pim">
#       PIM
#      </th>
#      <th class="regular pm" data-sort="pm">
#       +/-
#      </th>
#      <th class="separator">
#      </th>
#      <th class="postseason">
#       POST
#      </th>
#      <th class="postseason gp" data-sort="playoffs-gp">
#       GP
#      </th>
#      <th class="postseason g" data-sort="playoffs-g">
#       G
#      </th>
#      <th class="postseason a" data-sort="playoffs-a">
#       A
#      </th>
#      <th class="postseason tp" data-sort="playoffs-tp">
#       TP
#      </th>
#      <th class="postseason pim" data-sort="playoffs-pim">
#       PIM
#      </th>
#      <th class="postseason pm" data-sort="playoffs-pm">
#       +/-
#      </th>
#     </tr>
#    </thead>
#    <tbody>
#     <tr class="team-continent-NA">
#      <td class="season sorted">
#       2014-15
#      </td>
#      <td class="team">
#       <i>
#        <img src="images/flag.png"/>
#       </i>
#       <span class="txt-blue">
#        <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2014-2015?tab=stats">
#         MIT (Mass. Inst. of Tech.)
#        </a>
#       </span>
#      </td>
#      <td class="league">
#       <a href="https://www.eliteprospects.com/league/acha-ii/stats/2014-2015">
#        ACHA II
#       </a>
#      </td>
#      <td class="regular gp">
#       17
#      </td>
#      <td class="regular g">
#       3
#      </td>
#      <td class="regular a">
#       9
#      </td>
#      <td class="regular tp">
#       12
#      </td>
#      <td class="regular pim">
#       20
#      </td>
#      <td class="regular pm">
#      </td>
#      <td class="separator">
#       |
#      </td>
#      <td class="postseason">
#       <a href="https://www.eliteprospects.com/league/acha-ii/stats/2014-2015">
#       </a>
#      </td>
#      <td class="postseason gp">
#      </td>
#      <td class="postseason g">
#      </td>
#      <td class="postseason a">
#      </td>
#      <td class="postseason tp">
#      </td>
#      <td class="postseason pim">
#      </td>
#      <td class="postseason pm">
#      </td>
#     </tr>
#     <tr class="team-continent-NA">
#      <td class="season sorted">
#       2015-16
#      </td>
#      <td class="team">
#       <i>
#        <img src="images/flag.png"/>
#       </i>
#       <span class="txt-blue">
#        <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2015-2016?tab=stats">
#         MIT (Mass. Inst. of Tech.)
#        </a>
#       </span>
#      </td>
#      <td class="league">
#       <a href="https://www.eliteprospects.com/league/acha-ii/stats/2015-2016">
#        ACHA II
#       </a>
#      </td>
#      <td class="regular gp">
#       9
#      </td>
#      <td class="regular g">
#       1
#      </td>
#      <td class="regular a">
#       1
#      </td>
#      <td class="regular tp">
#       2
#      </td>
#      <td class="regular pim">
#       2
#      </td>
#      <td class="regular pm">
#      </td>
#      <td class="separator">
#       |
#      </td>
#      <td class="postseason">
#       <a href="https://www.eliteprospects.com/league/acha-ii/stats/2015-2016">
#       </a>
#      </td>
#      <td class="postseason gp">
#      </td>
#      <td class="postseason g">
#      </td>
#      <td class="postseason a">
#      </td>
#      <td class="postseason tp">
#      </td>
#      <td class="postseason pim">
#      </td>
#      <td class="postseason pm">
#      </td>
#     </tr>
#     <tr class="team-continent-NA">
#      <td class="season sorted">
#       2016-17
#      </td>
#      <td class="team">
#       <i>
#        <img src="images/flag.png"/>
#       </i>
#       <span class="txt-blue">
#        <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2016-2017?tab=stats">
#         MIT (Mass. Inst. of Tech.)
#        </a>
#       </span>
#      </td>
#      <td class="league">
#       <a href="https://www.eliteprospects.com/league/acha-ii/stats/2016-2017">
#        ACHA II
#       </a>
#      </td>
#      <td class="regular gp">
#       12
#      </td>
#      <td class="regular g">
#       5
#      </td>
#      <td class="regular a">
#       5
#      </td>
#      <td class="regular tp">
#       10
#      </td>
#      <td class="regular pim">
#       8
#      </td>
#      <td class="regular pm">
#       0
#      </td>
#      <td class="separator">
#       |
#      </td>
#      <td class="postseason">
#      </td>
#      <td class="postseason gp">
#      </td>
#      <td class="postseason g">
#      </td>
#      <td class="postseason a">
#      </td>
#      <td class="postseason tp">
#      </td>
#      <td class="postseason pim">
#      </td>
#      <td class="postseason pm">
#      </td>
#     </tr>
#     <tr class="team-continent-EU">
#      <td class="season sorted">
#       2017-18
#      </td>
#      <td class="team">
#       Did not play
#      </td>
#      <td class="league">
#       <a href="https://www.eliteprospects.com/stats">
#       </a>
#      </td>
#      <td class="regular gp">
#      </td>
#      <td class="regular g">
#      </td>
#      <td class="regular a">
#      </td>
#      <td class="regular tp">
#      </td>
#      <td class="regular pim">
#      </td>
#      <td class="regular pm">
#      </td>
#      <td class="separator">
#       |
#      </td>
#      <td class="postseason">
#       <a href="https://www.eliteprospects.com/stats">
#       </a>
#      </td>
#      <td class="postseason gp">
#      </td>
#      <td class="postseason g">
#      </td>
#      <td class="postseason a">
#      </td>
#      <td class="postseason tp">
#      </td>
#      <td class="postseason pim">
#      </td>
#      <td class="postseason pm">
#      </td>
#     </tr>
#     <tr class="team-continent-NA">
#      <td class="season sorted">
#       2018-19
#      </td>
#      <td class="team">
#       <i>
#        <img src="images/flag.png"/>
#       </i>
#       <span class="txt-blue">
#        <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2018-2019?tab=stats">
#         MIT (Mass. Inst. of Tech.)
#        </a>
#       </span>
#      </td>
#      <td class="league">
#       <a href="https://www.eliteprospects.com/league/acha-iii/stats/2018-2019">
#        ACHA III
#       </a>
#      </td>
#      <td class="regular gp">
#       8
#      </td>
#      <td class="regular g">
#       5
#      </td>
#      <td class="regular a">
#       10
#      </td>
#      <td class="regular tp">
#       15
#      </td>
#      <td class="regular pim">
#       8
#      </td>
#      <td class="regular pm">
#      </td>
#      <td class="separator">
#       |
#      </td>
#      <td class="postseason">
#       <a href="https://www.eliteprospects.com/league/acha-iii/stats/2018-2019">
#       </a>
#      </td>
#      <td class="postseason gp">
#      </td>
#      <td class="postseason g">
#      </td>
#      <td class="postseason a">
#      </td>
#      <td class="postseason tp">
#      </td>
#      <td class="postseason pim">
#      </td>
#      <td class="postseason pm">
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <h2>
#    Mystery Message Challenge!
#   </h2>
#   <p>
#    If you scrape the links below grabbing the &lt;p&gt; tag with id="secret-word", you'll discover a secret message :)
#   </p>
#   <div width="50%">
#    <div align="left" class="block">
#     <ul>
#      <li>
#       <a href="challenge/file_1.html">
#        File 1
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_2.html">
#        File 2
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_3.html">
#        File 3
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_4.html">
#        File 4
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_5.html">
#        File 5
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div align="center" class="block">
#     <ul>
#      <li>
#       <a href="challenge/file_6.html">
#        File 6
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_7.html">
#        File 7
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_8.html">
#        File 8
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_9.html">
#        File 9
#       </a>
#      </li>
#      <li>
#       <a href="challenge/file_10.html">
#        File 10
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <h2>
#    Footnotes
#   </h2>
#   <p id="footer">
#    1. This was actually a minivan that I named Debora. Maybe not my dream car, but I loved her nonetheless.
#   </p>
#  </body>
# </html>

# %%
#gRab all the social links from the webpage
links = webpage.select("a")
links
# Out:
# [<a href="https://www.youtube.com/kgmit">youtube.com/kgmit</a>,
#  <a href="#footer"><sup>1</sup></a>,
#  <a href="https://www.instagram.com/keithgalli/">https://www.instagram.com/keithgalli/</a>,
#  <a href="https://twitter.com/keithgalli">https://twitter.com/keithgalli</a>,
#  <a href="https://www.linkedin.com/in/keithgalli/">https://www.linkedin.com/in/keithgalli/</a>,
#  <a href="https://www.tiktok.com/@keithgalli">https://www.tiktok.com/@keithgalli</a>,
#  <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2014-2015?tab=stats"> MIT (Mass. Inst. of Tech.) </a>,
#  <a href="https://www.eliteprospects.com/league/acha-ii/stats/2014-2015"> ACHA II </a>,
#  <a href="https://www.eliteprospects.com/league/acha-ii/stats/2014-2015"> </a>,
#  <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2015-2016?tab=stats"> MIT (Mass. Inst. of Tech.) </a>,
#  <a href="https://www.eliteprospects.com/league/acha-ii/stats/2015-2016"> ACHA II </a>,
#  <a href="https://www.eliteprospects.com/league/acha-ii/stats/2015-2016"> </a>,
#  <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2016-2017?tab=stats"> MIT (Mass. Inst. of Tech.) </a>,
#  <a href="https://www.eliteprospects.com/league/acha-ii/stats/2016-2017"> ACHA II </a>,
#  <a href="https://www.eliteprospects.com/stats"> </a>,
#  <a href="https://www.eliteprospects.com/stats"> </a>,
#  <a href="https://www.eliteprospects.com/team/10263/mit-mass.-inst.-of-tech./2018-2019?tab=stats"> MIT (Mass. Inst. of Tech.) </a>,
#  <a href="https://www.eliteprospects.com/league/acha-iii/stats/2018-2019"> ACHA III </a>,
#  <a href="https://www.eliteprospects.com/league/acha-iii/stats/2018-2019"> </a>,
#  <a href="challenge/file_1.html">File 1</a>,
#  <a href="challenge/file_2.html">File 2</a>,
#  <a href="challenge/file_3.html">File 3</a>,
#  <a href="challenge/file_4.html">File 4</a>,
#  <a href="challenge/file_5.html">File 5</a>,
#  <a href="challenge/file_6.html">File 6</a>,
#  <a href="challenge/file_7.html">File 7</a>,
#  <a href="challenge/file_8.html">File 8</a>,
#  <a href="challenge/file_9.html">File 9</a>,
#  <a href="challenge/file_10.html">File 10</a>]

# %%
#Solution 1
links = webpage.select("ul.socials a")
actual_links = [link["href"] for link in links]
actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
#Solution 2
ulinks = webpage.find('ul', attrs={"class": "socials"})
links = ulinks.find_all("a")
actual_links = [link["href"] for link in links]
actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
#solution 3
links = webpage.select("li.social a")
actual_links = [link["href"] for link in links]
actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
#reference from stackoverflow
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
pd.DataFrame(l, columns=["A","B","C"])

# %%
#Scrape a table
import pandas as pd

table = webpage.select("table.hockey-stats")[0]
columns = table.find("thead").find_all("th")
column_names = [c.string for c in columns]


table_rows = table.find("tbody").find_all("tr")
l=[]
for tr in table_rows:
    td = tr.find_all('td')
    row = [str(tr.get_text()).strip() for tr in td]
    l.append(row)

df=pd.DataFrame(l, columns=column_names)
df["Team"]
# Out:
# 0    MIT (Mass. Inst. of Tech.)
# 1    MIT (Mass. Inst. of Tech.)
# 2    MIT (Mass. Inst. of Tech.)
# 3                  Did not play
# 4    MIT (Mass. Inst. of Tech.)
# Name: Team, dtype: object

# %%
d = requests.get("https://www.delcampe.net/en_GB")

#convert to bs object
sauce=bs(d.content)
paragraphs1 = sauce.find_all("div")
paragraphs1
# Out:
# [<div id="cookie-banner">
#  <div class="container flex space-lg lg-1 v-center">
#  <div class="main">
#  <p><strong class="font-xl">Information about cookies</strong></p>
#  <div class="margin-top-xxs">
#  <p>Our website uses cookies for the following purposes: to provide you with the services you have requested, to ensure the security of our platform, to remember your preferences in order to make your browsing more pleasant, to produce statistics in order to adapt our website to your needs, to offer you personalized advertising according to your interests.</p>
#  <p>Some of these cookies are necessary for the operation of our site, others can be set according to your preferences.
#                          <a href="/en_GB/cookies">More info</a>
#  </p>
#  </div>
#  </div>
#  <div class="flex space-xs sm-1 h-right">
#  <a class="btn-white" data-accept-cookies="" href="">Accept all cookies</a>
#  <a class="btn-white-outline" data-target="#cookie-modal" data-toggle="modal" href="">
#  <i class="fa fa-cog margin-right-sm"></i>Configure</a>
#  </div>
#  </div>
#  </div>,
#  <div class="container flex space-lg lg-1 v-center">
#  <div class="main">
#  <p><strong class="font-xl">Information about cookies</strong></p>
#  <div class="margin-top-xxs">
#  <p>Our website uses cookies for the following purposes: to provide you with the services you have requested, to ensure the security of our platform, to remember your preferences in order to make your browsing more pleasant, to produce statistics in order to adapt our website to your needs, to offer you personalized advertising according to your interests.</p>
#  <p>Some of these cookies are necessary for the operation of our site, others can be set according to your preferences.
#                          <a href="/en_GB/cookies">More info</a>
#  </p>
#  </div>
#  </div>
#  <div class="flex space-xs sm-1 h-right">
#  <a class="btn-white" data-accept-cookies="" href="">Accept all cookies</a>
#  <a class="btn-white-outline" data-target="#cookie-modal" data-toggle="modal" href="">
#  <i class="fa fa-cog margin-right-sm"></i>Configure</a>
#  </div>
#  </div>,
#  <div class="main">
#  <p><strong class="font-xl">Information about cookies</strong></p>
#  <div class="margin-top-xxs">
#  <p>Our website uses cookies for the following purposes: to provide you with the services you have requested, to ensure the security of our platform, to remember your preferences in order to make your browsing more pleasant, to produce statistics in order to adapt our website to your needs, to offer you personalized advertising according to your interests.</p>
#  <p>Some of these cookies are necessary for the operation of our site, others can be set according to your preferences.
#                          <a href="/en_GB/cookies">More info</a>
#  </p>
#  </div>
#  </div>,
#  <div class="margin-top-xxs">
#  <p>Our website uses cookies for the following purposes: to provide you with the services you have requested, to ensure the security of our platform, to remember your preferences in order to make your browsing more pleasant, to produce statistics in order to adapt our website to your needs, to offer you personalized advertising according to your interests.</p>
#  <p>Some of these cookies are necessary for the operation of our site, others can be set according to your preferences.
#                          <a href="/en_GB/cookies">More info</a>
#  </p>
#  </div>,
#  <div class="flex space-xs sm-1 h-right">
#  <a class="btn-white" data-accept-cookies="" href="">Accept all cookies</a>
#  <a class="btn-white-outline" data-target="#cookie-modal" data-toggle="modal" href="">
#  <i class="fa fa-cog margin-right-sm"></i>Configure</a>
#  </div>,
#  <div class="modal" id="cookie-modal">
#  <div class="modal-dialog modal-xl">
#  <div class="modal-content">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span class="close-text">Close</span>
#  <span aria-hidden="true" class="close-picto">×</span>
#  </button>
#  <div class="modal-header">
#  <h4 class="modal-title">Cookie settings</h4>
#  </div>
#  <div class="modal-body">
#  <p>Our website uses several types of cookies. Some of them are strictly necessary for the operation of our website. Others can be set according to your preferences.<br/>You can change your choices and withdraw your consent on this page at any time.</p>
#  <p>See our <a href="/en_GB/cookies">cookie usage policy</a> for more information.</p>
#  <ul class="list-border-grey no-list-sm margin-top-md">
#  <li><strong>Types of cookies allowed</strong></li>
#  <li><a data-remove-cookies="" href="">Deselect non-essential cookies</a></li>
#  </ul>
#  <ul class="nls flex space-md all-4 md-2 sm-1 margin-top-sm" id="cookie-types">
#  <li class="essentials">
#  <div class="bloc-white checked" data-cookie-type="essentials">
#  <span class="flex no-columns text-center font-bold no-margin">
#                                      Essential
#                                  </span>
#  </div>
#  </li>
#  <li class="functionnality">
#  <div class="bloc-white checked" data-cookie-type="functionnality">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="functionnality" id="delcampe_accept_cookie_law_groups_0" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="functional"/>
#
#                                          Functional
#                                      </label>
#  </div>
#  </li>
#  <li class="analytics">
#  <div class="bloc-white checked" data-cookie-type="analytics">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="analytics" id="delcampe_accept_cookie_law_groups_1" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="analytics"/>
#
#                                          Analytical
#                                      </label>
#  </div>
#  </li>
#  <li class="advertising">
#  <div class="bloc-white checked" data-cookie-type="advertising">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="advertising" id="delcampe_accept_cookie_law_groups_2" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="publicity"/>
#
#                                          Advertising
#                                      </label>
#  </div>
#  </li>
#  </ul>
#  <div class="cookie-content margin-top-md">
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal-footer bg-blue">
#  <button class="btn-orange btn-big" id="cookie-accept" type="submit">Save</button>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="modal-dialog modal-xl">
#  <div class="modal-content">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span class="close-text">Close</span>
#  <span aria-hidden="true" class="close-picto">×</span>
#  </button>
#  <div class="modal-header">
#  <h4 class="modal-title">Cookie settings</h4>
#  </div>
#  <div class="modal-body">
#  <p>Our website uses several types of cookies. Some of them are strictly necessary for the operation of our website. Others can be set according to your preferences.<br/>You can change your choices and withdraw your consent on this page at any time.</p>
#  <p>See our <a href="/en_GB/cookies">cookie usage policy</a> for more information.</p>
#  <ul class="list-border-grey no-list-sm margin-top-md">
#  <li><strong>Types of cookies allowed</strong></li>
#  <li><a data-remove-cookies="" href="">Deselect non-essential cookies</a></li>
#  </ul>
#  <ul class="nls flex space-md all-4 md-2 sm-1 margin-top-sm" id="cookie-types">
#  <li class="essentials">
#  <div class="bloc-white checked" data-cookie-type="essentials">
#  <span class="flex no-columns text-center font-bold no-margin">
#                                      Essential
#                                  </span>
#  </div>
#  </li>
#  <li class="functionnality">
#  <div class="bloc-white checked" data-cookie-type="functionnality">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="functionnality" id="delcampe_accept_cookie_law_groups_0" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="functional"/>
#
#                                          Functional
#                                      </label>
#  </div>
#  </li>
#  <li class="analytics">
#  <div class="bloc-white checked" data-cookie-type="analytics">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="analytics" id="delcampe_accept_cookie_law_groups_1" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="analytics"/>
#
#                                          Analytical
#                                      </label>
#  </div>
#  </li>
#  <li class="advertising">
#  <div class="bloc-white checked" data-cookie-type="advertising">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="advertising" id="delcampe_accept_cookie_law_groups_2" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="publicity"/>
#
#                                          Advertising
#                                      </label>
#  </div>
#  </li>
#  </ul>
#  <div class="cookie-content margin-top-md">
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal-footer bg-blue">
#  <button class="btn-orange btn-big" id="cookie-accept" type="submit">Save</button>
#  </div>
#  </div>
#  </div>,
#  <div class="modal-content">
#  <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#  <span class="close-text">Close</span>
#  <span aria-hidden="true" class="close-picto">×</span>
#  </button>
#  <div class="modal-header">
#  <h4 class="modal-title">Cookie settings</h4>
#  </div>
#  <div class="modal-body">
#  <p>Our website uses several types of cookies. Some of them are strictly necessary for the operation of our website. Others can be set according to your preferences.<br/>You can change your choices and withdraw your consent on this page at any time.</p>
#  <p>See our <a href="/en_GB/cookies">cookie usage policy</a> for more information.</p>
#  <ul class="list-border-grey no-list-sm margin-top-md">
#  <li><strong>Types of cookies allowed</strong></li>
#  <li><a data-remove-cookies="" href="">Deselect non-essential cookies</a></li>
#  </ul>
#  <ul class="nls flex space-md all-4 md-2 sm-1 margin-top-sm" id="cookie-types">
#  <li class="essentials">
#  <div class="bloc-white checked" data-cookie-type="essentials">
#  <span class="flex no-columns text-center font-bold no-margin">
#                                      Essential
#                                  </span>
#  </div>
#  </li>
#  <li class="functionnality">
#  <div class="bloc-white checked" data-cookie-type="functionnality">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="functionnality" id="delcampe_accept_cookie_law_groups_0" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="functional"/>
#
#                                          Functional
#                                      </label>
#  </div>
#  </li>
#  <li class="analytics">
#  <div class="bloc-white checked" data-cookie-type="analytics">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="analytics" id="delcampe_accept_cookie_law_groups_1" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="analytics"/>
#
#                                          Analytical
#                                      </label>
#  </div>
#  </li>
#  <li class="advertising">
#  <div class="bloc-white checked" data-cookie-type="advertising">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="advertising" id="delcampe_accept_cookie_law_groups_2" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="publicity"/>
#
#                                          Advertising
#                                      </label>
#  </div>
#  </li>
#  </ul>
#  <div class="cookie-content margin-top-md">
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal-footer bg-blue">
#  <button class="btn-orange btn-big" id="cookie-accept" type="submit">Save</button>
#  </div>
#  </div>,
#  <div class="modal-header">
#  <h4 class="modal-title">Cookie settings</h4>
#  </div>,
#  <div class="modal-body">
#  <p>Our website uses several types of cookies. Some of them are strictly necessary for the operation of our website. Others can be set according to your preferences.<br/>You can change your choices and withdraw your consent on this page at any time.</p>
#  <p>See our <a href="/en_GB/cookies">cookie usage policy</a> for more information.</p>
#  <ul class="list-border-grey no-list-sm margin-top-md">
#  <li><strong>Types of cookies allowed</strong></li>
#  <li><a data-remove-cookies="" href="">Deselect non-essential cookies</a></li>
#  </ul>
#  <ul class="nls flex space-md all-4 md-2 sm-1 margin-top-sm" id="cookie-types">
#  <li class="essentials">
#  <div class="bloc-white checked" data-cookie-type="essentials">
#  <span class="flex no-columns text-center font-bold no-margin">
#                                      Essential
#                                  </span>
#  </div>
#  </li>
#  <li class="functionnality">
#  <div class="bloc-white checked" data-cookie-type="functionnality">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="functionnality" id="delcampe_accept_cookie_law_groups_0" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="functional"/>
#
#                                          Functional
#                                      </label>
#  </div>
#  </li>
#  <li class="analytics">
#  <div class="bloc-white checked" data-cookie-type="analytics">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="analytics" id="delcampe_accept_cookie_law_groups_1" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="analytics"/>
#
#                                          Analytical
#                                      </label>
#  </div>
#  </li>
#  <li class="advertising">
#  <div class="bloc-white checked" data-cookie-type="advertising">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="advertising" id="delcampe_accept_cookie_law_groups_2" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="publicity"/>
#
#                                          Advertising
#                                      </label>
#  </div>
#  </li>
#  </ul>
#  <div class="cookie-content margin-top-md">
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="bloc-white checked" data-cookie-type="essentials">
#  <span class="flex no-columns text-center font-bold no-margin">
#                                      Essential
#                                  </span>
#  </div>,
#  <div class="bloc-white checked" data-cookie-type="functionnality">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="functionnality" id="delcampe_accept_cookie_law_groups_0" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="functional"/>
#
#                                          Functional
#                                      </label>
#  </div>,
#  <div class="bloc-white checked" data-cookie-type="analytics">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="analytics" id="delcampe_accept_cookie_law_groups_1" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="analytics"/>
#
#                                          Analytical
#                                      </label>
#  </div>,
#  <div class="bloc-white checked" data-cookie-type="advertising">
#  <label class="flex no-columns text-center font-bold no-margin">
#  <input checked="checked" class="hide" data-group-type="advertising" id="delcampe_accept_cookie_law_groups_2" name="delcampe_accept_cookie_law[groups][]" type="checkbox" value="publicity"/>
#
#                                          Advertising
#                                      </label>
#  </div>,
#  <div class="cookie-content margin-top-md">
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>
#  </div>,
#  <div class="flex all-2 sm-1 space-md" data-cookie-content="allowed">
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>
#  </div>,
#  <div data-allowed="">
#  <strong>What will be saved: </strong>
#  <ul class="list-check-green margin-top-sm" data-list="">
#  <li data-type="essentials">
#  <strong>Essential cookies (always required)</strong>
#  <p>These cookies are essential to the operation of many of our services.</p>
#  <p>Some of these cookies are also necessary to ensure the security of our website, for example in order to fight fraud.</p>
#  <p>These essential cookies are placed as soon as you access the site because they are required for navigation.</p>
#  </li>
#  <li data-type="functionnality">
#  <strong>Functional cookies</strong>
#  <p>These cookies collect information about your viewing and search choices and preferences to make your browsing experience more enjoyable and personalized.<br/>You may decline the use of these cookies.</p>
#  </li>
#  <li data-type="analytics">
#  <strong>Analytical cookies</strong>
#  <p>These cookies are used to collect information about your use of the site in order to improve its content, make it more relevant to your needs and increase its usability.</p>
#  <p>They also allow us to evaluate the effectiveness of our marketing campaigns.<br/>You can refuse cookies if you want to browse our website.</p>
#  </li>
#  <li data-type="advertising">
#  <strong>Advertising cookies</strong>
#  <p>These cookies are used for marketing purposes to display targeted advertising on the pages of our website and on the websites you visit next.</p>
#  <p>Rejecting these cookies will not affect your use of our website, but it will not stop advertising on our pages. It will only result in ads being displayed that do not reflect your preferences and interests.</p>
#  </li>
#  </ul>
#  </div>,
#  <div class="hide" data-not-allowed="">
#  <strong>What will not be saved: </strong>
#  <ul class="list-blocked-red margin-top-sm" data-list=""></ul>
#  </div>,
#  <div class="modal-footer bg-blue">
#  <button class="btn-orange btn-big" id="cookie-accept" type="submit">Save</button>
#  </div>,
#  <div class="menu-top" data-menu="">
#  <div class="container">
#  <ul class="nls main-list">
#  <li class="hide-min-sm">
#  <a class="go-back-menu" data-open-menu="" href="">Close<i class="pull-right">×</i></a>
#  </li>
#  <li>
#  <ul class="nls child-list"><li class="main-link register"><a class="font-bold" href="/en_GB/my-account/register">Sign up</a>
#  </li><li class="main-link dropdown arrow-white login">
#  <a class="hide-min-sm" href="/en_GB/my-account/login">Login</a>
#  <a aria-expanded="false" class="dropdown-toggle hide-max-sm login-dropdown" data-signin-link="" data-toggle="dropdown" href="/en_GB/my-account/login">Login</a>
#  <div class="dropdown-menu" role="form">
#  <form action="/en_GB/my-account/login" method="post" name="user_login" novalidate="novalidate">
#  <div class="form-group">
#  <input class="form-control" data-lpignore="true" focus="focus" id="user_login_nickname" name="user_login[nickname]" placeholder="Nickname" required="required" type="text"/>
#  </div>
#  <div class="form-group">
#  <input class="form-control" data-lpignore="true" id="user_login_password" maxlength="25" minlength="6" name="user_login[password]" placeholder="Password" required="required" type="password"/>
#  </div>
#  <div class="remember-me">
#  <label class="line-height-sm font-xs" for="remember_me">
#  <input checked="" id="remember_me" name="_remember_me" type="checkbox"/>Stay signed in of this device
#                                  </label>
#  </div>
#  <input name="_csrf_token" type="hidden" value="5cc94a10837712545bd1.UyS8jrQk-_fVcC6A1DKRBPKB7pCtpW3VzcyXxXM-2Xc.PWGK_-1nqaOZEmHNnULOXIb7qPj88y6X-pTUjQRnikQdT8Xow0mTmr4BQQ"/>
#  <input name="_target_path" type="hidden" value="https://www.delcampe.net/en_GB/collectables/"/>
#  <button class="btn-block btn-orange margin-top-xs" type="submit">Login</button>
#  <a class="text-center" href="/en_GB/my-account/reset-password">Reset your password</a>
#  <input id="user_login__token" name="user_login[_token]" type="hidden" value="767a7dedd6.SbDJPK2KkifO4nLWywkypN2DqYT4jVztWPf8dCoTByw.JdGieZuy3G-3tQKApWJc3b_B_720vDK7AJi6WUlpcW4F4INJxf7EfbiyKw"/></form>
#  </div>
#  </li></ul>
#  </li>
#  <li>
#  <ul class="nls child-list">
#  <li class="dropdown arrow-white buy-menu" data-parent-slide="">
#  <a aria-expanded="false" class="dropdown-toggle" data-toggle="dropdown" data-toggle-menu="" href="/en_GB/collectables/buy/purchases/purchased-items" rel="nofollow" role="button">Buy</a>
#  <div class="dropdown-menu" data-slide="" role="menu">
#  <div class="flex md-1">
#  <ul class="nls links-list">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">Search</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/search/by-keywords">Advanced search</a>
#  </li>
#  <li class="margin-top-sm"> <a href="/en_GB/collectables/category">All categories</a>
#  </li>
#  <li> <a href="/en_GB/vintage">Vintage Universe</a>
#  </li>
#  <li> <a href="/en_GB/prestige/catalogs/list/opened">Auction Houses catalogues</a>
#  </li>
#  <li class="margin-top-sm"> <a href="/en_GB/collectables/top-stores">Top Shops</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My favourites</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/favorites/watching-list">Watching list</a>
#  </li>
#  <li> <a href="/en_GB/collectables/favorites/favorites-list">Favourite searches</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/favorites/favorites-list">My favourite lists</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="nls links-list">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My bids</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/bids/ongoing">Ongoing</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/bids/lost">Lost</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/bids/lower-proposed">Lower</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/bids/bid-group-proposed">Grouped</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/bids/auction-house">Auction houses</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My purchases</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/purchases/purchased-items">All</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/purchases/awaiting-invoice">Awaiting invoice</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/purchases/awaiting-payment">Awaiting payment</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/purchases/awaiting-shipment">Awaiting shipment</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/purchases/received">Received</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/purchases/archived">Archived</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="nls links-list">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My feedback</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/feedback/leave-feedback">Leave feedback</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/feedback/received-list">Received</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/feedback/given-list">Given</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">History</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/purchases/purchased-items/list">All my purchased items</a>
#  </li>
#  <li> <a href="/en_GB/collectables/buy/payments/sent">Payments sent</a>
#  </li></ul>
#  </li>
#  <li class="more-links" data-parent-slide="">
#  <span class="list-title hide-min-sm" data-toggle-menu="">More links</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/buy/buying-stats">My buying stats</a>
#  </li>
#  <li> <a href="/en_GB/my-account/blacklist/i-block-sellers">Seller blacklist</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="delcampe-pay-menu nls links-list bg-blue-light">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">Delcampe Pay<i class="delcampe-pay-logo"></i></span>
#  <ul class="nls sub-menu-slide" data-slide=""><div class="no-delcampe-pay-account font-md">
#  <p class="font-sm margin-top-xs margin-bottom-sm">Activate your Delcampe Pay account to pay for your purchases or receive payments for your Delcampe sales.</p>
#  <div class="flex space-sm v-center margin-bottom-sm">
#  <img alt="easy" src="https://www.delcampe.net/images/delcampe-pay/easy.png?v=1667652553"/>
#  <strong>User-friendly</strong>
#  </div>
#  <div class="flex space-sm v-center margin-bottom-sm">
#  <img alt="cheaper" src="https://www.delcampe.net/images/delcampe-pay/cheaper.png?v=1667652553"/>
#  <strong>One of the cheapest payment methods</strong>
#  </div>
#  <div class="flex space-sm v-center margin-bottom-md">
#  <img alt="security" src="https://www.delcampe.net/images/icon/lock.svg?v=1667652553"/>
#  <strong>Completely secure</strong>
#  </div>
#  <a class="btn-block btn-big btn-green" href="/en_GB/delcampe-pay/">Discover Delcampe Pay</a>
#  </div></ul>
#  </li>
#  </ul> </div>
#  </div>
#  </li>
#  <li class="dropdown arrow-white sell-menu" data-parent-slide="">
#  <a aria-expanded="false" class="dropdown-toggle" data-toggle="dropdown" data-toggle-menu="" href="/en_GB/collectables/item/sell" rel="nofollow" role="button">Sell</a>
#  <div class="dropdown-menu" data-slide="" role="menu"><div class="flex md-1">
#  <ul class="nls links-list">
#  <li class="put-on-sale" data-parent-slide="">
#  <a class="btn-orange btn-big btn-block" href="/en_GB/collectables/item/sell">Sell</a>
#  <div class="text-center margin-top-xs"> <a href="/en_GB/selling-methods">Selling methods</a>
#  </div>
#  </li>
#  <li class="more-links" data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My items for sale</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/item-for-sale/ongoing">Ongoing</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/item-for-sale/ongoing-with-offers">Ongoing with bids</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/item-for-sale/bid-lower-received">Lower bids received</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/item-for-sale/bid-group-received">Grouped bids received</a>
#  </li>
#  <li class="margin-top-sm"> <a href="/en_GB/sell/apply-shipping-model">Management of shipping costs</a>
#  </li>
#  <li class="margin-top-sm"> <a href="/en_GB/collectables/sell/multiple-edit">Multiple changes</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My unsold items</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/unsold-items/closed-list">Closed</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/unsold-items/archived-list">Archived</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="nls links-list">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My sold items</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/sold-items/list">All</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/sold-items/to-invoice">To invoice</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/sold-items/invoiced">Invoiced</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/sold-items/to-send">Awaiting shipment</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/sold-items/sent">Shipped</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/sold-items/archived">Archived</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My store</span>
#  <ul class="nls sub-menu-slide" data-slide=""><li> <a href="/en_GB/collectables/store-settings/payment-methods">Shop configuration</a>
#  </li>
#  <li> <a href="/en_GB/collectables/store-settings/customization">Shop settings</a>
#  </li>
#  <li> <a href="/en_GB/collectables/store-settings/shipping-models">Fee templates</a>
#  </li>
#  <li> <a href="/en_GB/collectables/store-settings/sales-conditions">Sales Conditions</a>
#  </li>
#  <li> <a href="/en_GB/collectables/store-settings/payment-methods">Payment methods</a>
#  </li>
#  <li> <a href="/en_GB/my-account/store-blacklist">My shop in the blacklist</a>
#  </li><li> <a href="/en_GB/api">Delcampe API</a>
#  </li></ul>
#  </li>
#  </ul>
#  <ul class="nls links-list">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">My feedback</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/feedback/leave-feedback">Leave feedback</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/feedback/received-list">Received</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/feedback/given-list">Given</a>
#  </li>
#  </ul>
#  </li>
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">History</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/sold-items/items-list">All my sold items</a>
#  </li>
#  <li> <a href="/en_GB/collectables/sell/payment/received-list">Payments received</a>
#  </li></ul>
#  </li>
#  <li class="more-links" data-parent-slide="">
#  <span class="list-title hide-min-sm" data-toggle-menu="">More links</span>
#  <ul class="nls sub-menu-slide" data-slide="">
#  <li> <a href="/en_GB/collectables/sell/selling-stats">My selling stats</a>
#  </li>
#  <li> <a href="/en_GB/my-account/blacklist/i-block-buyers">Buyer blacklist</a>
#  </li>
#  <li class="margin-top-sm padding-top-sm border-top-blue-grey"> <a href="/en_GB/forum-estimation">Estimate my item</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="delcampe-pay-menu nls links-list bg-blue-light">
#  <li data-parent-slide="">
#  <span class="list-title" data-toggle-menu="">Delcampe Pay<i class="delcampe-pay-logo"></i></span>
#  <ul class="nls sub-menu-slide" data-slide=""><div class="no-delcampe-pay-account font-md">
#  <p class="font-sm margin-top-xs margin-bottom-sm">Activate your Delcampe Pay account to pay for your purchases or receive payments for your Delcampe sales.</p>
#  <div class="flex space-sm v-center margin-bottom-sm">
#  <img alt="easy" src="https://www.delcampe.net/images/delcampe-pay/easy.png?v=1667652553"/>
#  <strong>User-friendly</strong>
#  </div>
#  <div class="flex space-sm v-center margin-bottom-sm">
#  <img alt="cheaper" src="https://www.delcampe.net/images/delcampe-pay/cheaper.png?v=1667652553"/>
#  <strong>One of the cheapest payment methods</strong>
#  </div>
#  <div class="flex space-sm v-center margin-bottom-md">
#  <img alt="security" src="https://www.delcampe.net/images/icon/lock.svg?v=1667652553"/>
#  <strong>Completely secure</strong>
#  </div>
#  <a class="btn-block btn-big btn-green" href="/en_GB/delcampe-pay/">Discover Delcampe Pay</a>
#  </div></ul>
#  </li>
#  </ul> </div>
#  </div>
#  </li>
#  <li class="dropdown arrow-white community-menu" data-parent-slide="">
#  <a aria-expanded="false" class="dropdown-toggle" data-toggle="dropdown" data-toggle-menu="" href="/en_GB/forum" rel="nofollow" role="button">Community</a>
#  <div class="dropdown-menu" data-slide="" role="menu">
#  <div class="flex md-1">
#  <ul class="nls links-list">
#  <li> <a href="/en_GB/forum">Forum</a>
#  </li>
#  <li> <a href="/en_GB/agenda/">Calendar</a>
#  </li>
#  <li><a href="https://blog.delcampe.net/en" target="_blank">Blog</a></li>
#  <li><a href="https://blog.delcampe.net/en/magazine" target="_blank">Magazine</a></li>
#  <li> <a href="/en_GB/youtube">Videos</a>
#  </li>
#  <li>
#  <ul class="nls list-inline margin-top-lg">
#  <li><a class="button-social facebook" href="https://www.facebook.com/delcampe" rel="nofollow noopener noreferrer" target="_blank" title="Facebook"><i class="fa fa-facebook"></i></a></li>
#  <li><a class="button-social linkedin" href="https://www.linkedin.com/company/delcampe-international-sprl" rel="nofollow noopener noreferrer" target="_blank" title="Linkedin"><i class="fa fa-linkedin"></i></a></li>
#  <li><a class="button-social youtube" href="https://www.youtube.com/delcampeofficial" rel="nofollow noopener noreferrer" target="_blank" title="Youtube"><i class="fa fa-youtube-play"></i></a></li>
#  <li><a class="button-social twitter" href="https://twitter.com/Delcampe" rel="nofollow noopener noreferrer" target="_blank" title="Twitter"><i class="fa fa-twitter"></i></a></li>
#  <li><a class="button-social instagram" href="https://www.instagram.com/delcampe_official" rel="nofollow noopener noreferrer" target="_blank" title="Instagram"><i class="fa fa-instagram"></i></a></li>
#  <li><a class="button-social pinterest" href="https://pinterest.com/delcampe_marketplace" rel="nofollow noopener noreferrer" target="_blank" title="Pinterest"><i class="fa fa-pinterest"></i></a></li>
#  </ul>
#  </li>
#  </ul>
#  <div class="main">
#  <div class="flex md-1"><ul class="nls links-list bg-blue-light" id="blog">
#  <li class="flex md-1 space-md v-center">
#  <a class="no-margin-bottom" href="https://blog.delcampe.net/en" target="_blank">
#  <img alt="Blog" data-lazyload-menu="" data-original="https://www.delcampe.net/images/homepage/banner-top/blog.png?v=1667652553" src=""/>
#  </a>
#  <span class="no-margin-bottom">
#  <strong>Discover our articles on your collection.</strong>
#  <a class="btn-orange nowrap" href="https://blog.delcampe.net/en" target="_blank">Read the Delcampe Blog</a>
#  </span>
#  </li>
#  </ul><ul class="nls links-list bg-blue-light flex v-center" id="agenda">
#  <li class="flex space-md v-center">
#  <a href="/en_GB/agenda/"><img alt="Calendar" src="https://www.delcampe.net/images/homepage/agenda.jpg?v=1667652553"/></a>
#  <span>
#  <strong>Discover the collectors' agenda!</strong>
#  <a class="btn-orange" href="/en_GB/agenda/">Discover the agenda</a>
#  </span>
#  </li>
#  </ul></div>
#  <div class="menu-community-youtube flex md-1">
#  <div class="links-list">
#  <div class="flex space-md v-center">
#  <a class="thumb-video" href="https://www.youtube.com/watch?v=dCZB-bKFMcA&amp;list=PLFD6XaVCwAhFsT2RrABRUP6U59iJbGQIl" target="_blank">
#  <img alt="MONUMENTAL ERROR on this SUEZ CANAL STAMP! | The World of Collecting" height="70" loading="lazy" src="https://i.ytimg.com/vi/dCZB-bKFMcA/mqdefault.jpg" width="125"/>
#  </a>
#  <a class="line-height-xs" href="https://www.youtube.com/watch?v=dCZB-bKFMcA&amp;list=PLFD6XaVCwAhFsT2RrABRUP6U59iJbGQIl">MONUMENTAL ERROR on this SUEZ CANAL STAMP! | The World of Collecting</a>
#  </div>
#  </div>
#  <div class="links-list">
#  <div class="flex space-md v-center">
#  <a class="thumb-video" href="https://www.youtube.com/watch?v=2Xjdtd55lDo&amp;list=PLFD6XaVCwAhGT98UT4xTqDlM9xjacnV7i" target="_blank">
#  <img alt="Top sales on Delcampe (October 2022) | The collectables of the marketplace" height="70" loading="lazy" src="https://i.ytimg.com/vi/2Xjdtd55lDo/mqdefault.jpg" width="125"/>
#  </a>
#  <a class="line-height-xs" href="https://www.youtube.com/watch?v=2Xjdtd55lDo&amp;list=PLFD6XaVCwAhGT98UT4xTqDlM9xjacnV7i">Top sales on Delcampe (October 2022) | The collectables of the marketplace</a>
#  </div>
#  </div>
#  </div>
#  </div> </div>
#  </div>
#  </li>
#  </ul>
#  </li>
#  <li class="main">
#  <ul class="nls child-list">
#  <li class="no-dropdown helpcenter">
#  <a href="/en_GB/help-center" title="Help centre">
#  <i class="fa fa-question-circle in-block"></i>
#  <span class="hide">Help centre</span>
#  </a>
#  </li>
#  <li class="align-right no-dropdown favorites">
#  <a href="/en_GB/collectables/favorites/favorites-list" title="My favourites">
#  <i class="fa fa-star in-block"></i>
#  <span class="hide-lg">Favourites</span>
#  </a>
#  </li>
#  <li class="no-dropdown watching-list">
#  <a href="/en_GB/collectables/buy/favorites/watching-list" title="Watching list">
#  <i class="fa fa-heart in-block"></i>
#  <span class="hide-lg">Watching list</span>
#  </a>
#  </li>
#  <li class="no-dropdown basket-container">
#  <a class="basket" data-go-basket="" href="/en_GB/collectables/basket" title="My shopping cart">
#  <i class="fa fa-shopping-cart in-block"></i>
#  <span class="hide-lg">Cart</span></a>
#  </li>
#  <li class="dropdown arrow-white langages not-full-width" data-parent-slide="">
#  <a aria-expanded="false" class="dropdown-toggle" data-toggle="dropdown" data-toggle-menu="" href="#">English (United Kingdom)</a>
#  <ul class="dropdown-menu small-dropdown" data-slide="" role="menu"><li><a href="https://www.delcampe.net/fr/collections/">Français</a></li><li><a href="https://www.delcampe.net/en_US/collectibles/">English (United States)</a></li><li><a href="https://www.delcampe.net/nl/verzamelingen/">Nederlands</a></li><li><a href="https://www.delcampe.net/de/sammlerobjekte/">Deutsch</a></li><li><a href="https://www.delcampe.net/it/collezionismo/">Italiano</a></li><li><a href="https://www.delcampe.net/es/coleccionismo/">Español</a></li></ul>
#  </li></ul>
#  </li></ul>
#  </div>
#  </div>,
#  <div class="container">
# ...
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div>,
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>,
#  <div>
#  <div class="img-view">
#  <a href="/en_GB/collectables/postcards/illustrators-photographers/bouret-germaine/ii-germaine-bouret-union-nationale-des-associations-regionales-pour-la-sauvegarde-de-lenfance-et-de-ladolescence-n-4-1641276413.html" title="II ) Germaine Bouret Union Nationale des Associations Régionales Pour la Sauvegarde de L'Enfance et de L'Adolescence N°4">
#  <img alt="II ) Germaine Bouret Union Nationale Des Associations Régionales Pour La Sauvegarde De L'Enfance Et De L'Adolescence N°4 - Bouret, Germaine" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="II ) Germaine Bouret Union Nationale Des Associations Régionales Pour La Sauvegarde De L'Enfance Et De L'Adolescence N°4 - Bouret, Germaine" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3"/>
#  </noscript>
#  </a>
#  </div>
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€25.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/postcards/illustrators-photographers/bouret-germaine/ii-germaine-bouret-union-nationale-des-associations-regionales-pour-la-sauvegarde-de-lenfance-et-de-ladolescence-n-4-1641276413.html">Discover</a>
#  </div>
#  </div>,
#  <div class="img-view">
#  <a href="/en_GB/collectables/postcards/illustrators-photographers/bouret-germaine/ii-germaine-bouret-union-nationale-des-associations-regionales-pour-la-sauvegarde-de-lenfance-et-de-ladolescence-n-4-1641276413.html" title="II ) Germaine Bouret Union Nationale des Associations Régionales Pour la Sauvegarde de L'Enfance et de L'Adolescence N°4">
#  <img alt="II ) Germaine Bouret Union Nationale Des Associations Régionales Pour La Sauvegarde De L'Enfance Et De L'Adolescence N°4 - Bouret, Germaine" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="II ) Germaine Bouret Union Nationale Des Associations Régionales Pour La Sauvegarde De L'Enfance Et De L'Adolescence N°4 - Bouret, Germaine" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/641/276/413_001.jpg?v=3"/>
#  </noscript>
#  </a>
#  </div>,
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€25.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/postcards/illustrators-photographers/bouret-germaine/ii-germaine-bouret-union-nationale-des-associations-regionales-pour-la-sauvegarde-de-lenfance-et-de-ladolescence-n-4-1641276413.html">Discover</a>
#  </div>,
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€25.00</strong>
#  </div>,
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div>,
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>,
#  <div>
#  <div class="img-view">
#  <a href="/en_GB/collectables/stamps/belgium-postmark-collection/fortune-cancels-1919/cob-135-sur-cpa-bruxelles-place-de-brouckere-obliteration-de-fortune-obaix-buzet-simple-cercle-xix-siecle-1597030846.html" title="COB 135 sur CPA Bruxelles place de Brouckère obliteration de fortune obaix buzet - simple cercle XIX siecle">
#  <img alt="COB 135 Sur CPA Bruxelles Place De Brouckère Obliteration De Fortune Obaix Buzet - Simple Cercle XIX Siecle - Fortune Cancels (1919)" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="COB 135 Sur CPA Bruxelles Place De Brouckère Obliteration De Fortune Obaix Buzet - Simple Cercle XIX Siecle - Fortune Cancels (1919)" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€50.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/stamps/belgium-postmark-collection/fortune-cancels-1919/cob-135-sur-cpa-bruxelles-place-de-brouckere-obliteration-de-fortune-obaix-buzet-simple-cercle-xix-siecle-1597030846.html">Discover</a>
#  </div>
#  </div>,
#  <div class="img-view">
#  <a href="/en_GB/collectables/stamps/belgium-postmark-collection/fortune-cancels-1919/cob-135-sur-cpa-bruxelles-place-de-brouckere-obliteration-de-fortune-obaix-buzet-simple-cercle-xix-siecle-1597030846.html" title="COB 135 sur CPA Bruxelles place de Brouckère obliteration de fortune obaix buzet - simple cercle XIX siecle">
#  <img alt="COB 135 Sur CPA Bruxelles Place De Brouckère Obliteration De Fortune Obaix Buzet - Simple Cercle XIX Siecle - Fortune Cancels (1919)" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="COB 135 Sur CPA Bruxelles Place De Brouckère Obliteration De Fortune Obaix Buzet - Simple Cercle XIX Siecle - Fortune Cancels (1919)" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/597/030/846_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>,
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€50.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/stamps/belgium-postmark-collection/fortune-cancels-1919/cob-135-sur-cpa-bruxelles-place-de-brouckere-obliteration-de-fortune-obaix-buzet-simple-cercle-xix-siecle-1597030846.html">Discover</a>
#  </div>,
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€50.00</strong>
#  </div>,
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div>,
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>,
#  <div>
#  <div class="img-view">
#  <a href="/en_GB/collectables/postcards/illustrators-photographers/kirchner-raphael/cpa-illustrateur-raphael-kirchner-la-baigneuse-femme-avec-maillot-de-bain-transparent-erotique-1590842245.html" title="CPA illustrateur Raphael Kirchner - La baigneuse - femme avec maillot de bain transparent - erotique">
#  <img alt="CPA Illustrateur Raphael Kirchner - La Baigneuse - Femme Avec Maillot De Bain Transparent - Erotique - Kirchner, Raphael" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="CPA Illustrateur Raphael Kirchner - La Baigneuse - Femme Avec Maillot De Bain Transparent - Erotique - Kirchner, Raphael" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€42.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/postcards/illustrators-photographers/kirchner-raphael/cpa-illustrateur-raphael-kirchner-la-baigneuse-femme-avec-maillot-de-bain-transparent-erotique-1590842245.html">Discover</a>
#  </div>
#  </div>,
#  <div class="img-view">
#  <a href="/en_GB/collectables/postcards/illustrators-photographers/kirchner-raphael/cpa-illustrateur-raphael-kirchner-la-baigneuse-femme-avec-maillot-de-bain-transparent-erotique-1590842245.html" title="CPA illustrateur Raphael Kirchner - La baigneuse - femme avec maillot de bain transparent - erotique">
#  <img alt="CPA Illustrateur Raphael Kirchner - La Baigneuse - Femme Avec Maillot De Bain Transparent - Erotique - Kirchner, Raphael" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="CPA Illustrateur Raphael Kirchner - La Baigneuse - Femme Avec Maillot De Bain Transparent - Erotique - Kirchner, Raphael" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/590/842/245_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>,
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€42.00</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/postcards/illustrators-photographers/kirchner-raphael/cpa-illustrateur-raphael-kirchner-la-baigneuse-femme-avec-maillot-de-bain-transparent-erotique-1590842245.html">Discover</a>
#  </div>,
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€42.00</strong>
#  </div>,
#  <div class="selling-type" title="Auction">
#  <span class="selling-type-icon bid"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>
#  </div>,
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              Auction
#                      </span>
#  </div>,
#  <div>
#  <div class="img-view">
#  <a href="/en_GB/collectables/stamps/congo-kinshasa-belgian-congo/collections/congo-belge-dans-un-album-entre-1886-et-1922-neuf-charnieres-et-oblitere-voir-les-photos-1645154699.html" title="Congo Belge dans un album entre 1886 et 1922 Neuf* charnières et oblitéré voir les photos">
#  <img alt="Congo Belge Dans Un Album Entre 1886 Et 1922 Neuf* Charnières Et Oblitéré Voir Les Photos - Collections" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="Congo Belge Dans Un Album Entre 1886 Et 1922 Neuf* Charnières Et Oblitéré Voir Les Photos - Collections" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction: 29 bids">
#  <span class="selling-type-icon bid orange"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              29 bids
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€68.50</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/stamps/congo-kinshasa-belgian-congo/collections/congo-belge-dans-un-album-entre-1886-et-1922-neuf-charnieres-et-oblitere-voir-les-photos-1645154699.html">Discover</a>
#  </div>
#  </div>,
#  <div class="img-view">
#  <a href="/en_GB/collectables/stamps/congo-kinshasa-belgian-congo/collections/congo-belge-dans-un-album-entre-1886-et-1922-neuf-charnieres-et-oblitere-voir-les-photos-1645154699.html" title="Congo Belge dans un album entre 1886 et 1922 Neuf* charnières et oblitéré voir les photos">
#  <img alt="Congo Belge Dans Un Album Entre 1886 Et 1922 Neuf* Charnières Et Oblitéré Voir Les Photos - Collections" class="image-thumb" data-image-number="1" data-lazy="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1" data-lazyload="" data-original="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1" height="178" itemprop="image" loading="lazy"/>
#  <noscript>
#  <img alt="Congo Belge Dans Un Album Entre 1886 Et 1922 Neuf* Charnières Et Oblitéré Voir Les Photos - Collections" class="image-thumb" src="https://www.delcampe.net/static/img_thumb/auction/001/645/154/699_001.jpg?v=1"/>
#  </noscript>
#  </a>
#  </div>,
#  <div class="description">
#  <div class="flex space-md">
#  <div class="selling-type" title="Auction: 29 bids">
#  <span class="selling-type-icon bid orange"></span>
#  <div class="selling-type-right">
#  <span class="selling-type-text">
#                              29 bids
#                      </span>
#  </div>
#  </div> <strong class="selling-price align-right">€68.50</strong>
#  </div>
#  <a class="btn-orange btn-big btn-block margin-top-sm" href="/en_GB/collectables/stamps/congo-kinshasa-belgian-congo/collections/congo-belge-dans-un-album-entre-1886-et-1922-neuf-charnieres-et-oblitere-voir-les-photos-1645154699.html">Discover</a>
#  </div>,
#  ...]
